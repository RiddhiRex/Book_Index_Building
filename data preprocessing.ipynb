# %%
import subprocess
import pandas as pd
import re
import glob

# %%
input_text={}

for filename in glob.glob("calculus/*/*.tex"):
    try:
        process = subprocess.Popen(['detex', filename], stdout=subprocess.PIPE)
    except FileNotFoundError:
        raise FileNotFoundError("Please verify that detex is installed on your sysread_booktem. https://github.com/pkubowicz/opendetex")
    
    output, err = process.communicate()
    input_text[filename] = str(output)
    input_text[filename] = ' '.join(input_text[filename].split('\\n'))
    
for key in input_text:
    print(key)
    #print(input_text[key])
# Out:
# calculus/ch07/ch07.tex
# calculus/ch03/ch03.tex
# calculus/ch09/ch09.tex
# calculus/ch01/ch01.tex
# calculus/ch05/ch05.tex
# calculus/ch06/ch06.tex
# calculus/ch02/ch02.tex
# calculus/ch08/ch08.tex
# calculus/ch04/ch04.tex

# %%
for filename in glob.glob("discover_physics/*/*.tex"):
    try:
        process = subprocess.Popen(['detex', filename], stdout=subprocess.PIPE)
    except FileNotFoundError:
        raise FileNotFoundError("Please verify that detex is installed on your sysread_booktem. https://github.com/pkubowicz/opendetex")
    
    output, err = process.communicate()
    input_text[filename] = str(output)
    input_text[filename] = ' '.join(input_text[filename].split('\\n'))
for key in input_text:
    print(key)
# Out:
# calculus/ch07/ch07.tex
# calculus/ch03/ch03.tex
# discover_physics/ch04/ch04.tex
# discover_physics/ch03/ch03.tex
# calculus/ch02/ch02.tex
# calculus/ch08/ch08.tex
# calculus/ch09/ch09.tex
# discover_physics/ch06/ch06.tex
# discover_physics/ch07/ch07.tex
# discover_physics/ch02/ch02.tex
# calculus/ch04/ch04.tex
# calculus/ch01/ch01.tex
# calculus/ch05/ch05.tex
# calculus/ch06/ch06.tex
# discover_physics/ch01/ch01.tex
# discover_physics/ch05/ch05.tex

# %%
for filename in glob.glob("fundamentals-of-calculus/*/*.rbtex"):
    try:
        process = subprocess.Popen(['detex', filename], stdout=subprocess.PIPE)
    except FileNotFoundError:
        raise FileNotFoundError("Please verify that detex is installed on your sysread_booktem. https://github.com/pkubowicz/opendetex")
    
    output, err = process.communicate()
    input_text[filename] = str(output)
    input_text[filename] = ' '.join(input_text[filename].split('\\n'))
for key in input_text:
    print(key)
# Out:
# calculus/ch07/ch07.tex
# calculus/ch03/ch03.tex
# fundamentals-of-calculus/ch04/ch04.rbtex
# discover_physics/ch04/ch04.tex
# fundamentals-of-calculus/ch06/ch06.rbtex
# fundamentals-of-calculus/ch02/ch02.rbtex
# calculus/ch08/ch08.tex
# calculus/ch09/ch09.tex
# fundamentals-of-calculus/ch10/ch10.rbtex
# fundamentals-of-calculus/ch03/ch03.rbtex
# discover_physics/ch07/ch07.tex
# discover_physics/ch02/ch02.tex
# calculus/ch01/ch01.tex
# discover_physics/ch06/ch06.tex
# fundamentals-of-calculus/ch05/ch05.rbtex
# calculus/ch06/ch06.tex
# fundamentals-of-calculus/ch07/ch07.rbtex
# fundamentals-of-calculus/ch08/ch08.rbtex
# calculus/ch02/ch02.tex
# discover_physics/ch03/ch03.tex
# calculus/ch04/ch04.tex
# fundamentals-of-calculus/ch09/ch09.rbtex
# fundamentals-of-calculus/end/photocredits.rbtex
# calculus/ch05/ch05.tex
# fundamentals-of-calculus/ch01/ch01.rbtex
# discover_physics/ch01/ch01.tex
# discover_physics/ch05/ch05.tex
# ...

# %%
for filename in glob.glob("general_relativity/*/*.rbtex"):
    try:
        process = subprocess.Popen(['detex', filename], stdout=subprocess.PIPE)
    except FileNotFoundError:
        raise FileNotFoundError("Please verify that detex is installed on your sysread_booktem. https://github.com/pkubowicz/opendetex")
    
    output, err = process.communicate()
    input_text[filename] = str(output)
    input_text[filename] = ' '.join(input_text[filename].split('\\n'))
for key in input_text:
    print(key)
# Out:
# calculus/ch07/ch07.tex
# calculus/ch03/ch03.tex
# fundamentals-of-calculus/ch04/ch04.rbtex
# discover_physics/ch04/ch04.tex
# general_relativity/ch08/ch08.rbtex
# fundamentals-of-calculus/ch06/ch06.rbtex
# general_relativity/ch03/ch03.rbtex
# fundamentals-of-calculus/ch02/ch02.rbtex
# calculus/ch08/ch08.tex
# calculus/ch09/ch09.tex
# fundamentals-of-calculus/ch10/ch10.rbtex
# fundamentals-of-calculus/ch03/ch03.rbtex
# discover_physics/ch07/ch07.tex
# discover_physics/ch02/ch02.tex
# general_relativity/ch07/ch07.rbtex
# calculus/ch01/ch01.tex
# discover_physics/ch06/ch06.tex
# fundamentals-of-calculus/ch05/ch05.rbtex
# calculus/ch06/ch06.tex
# general_relativity/ch05/ch05.rbtex
# general_relativity/ch09/ch09.rbtex
# general_relativity/ch01/ch01.rbtex
# general_relativity/ch06/ch06.rbtex
# general_relativity/ch02/ch02.rbtex
# fundamentals-of-calculus/ch07/ch07.rbtex
# fundamentals-of-calculus/ch08/ch08.rbtex
# general_relativity/ch04/ch04.rbtex
# calculus/ch02/ch02.tex
# ...

# %%
for filename in glob.glob("special_relativity/*/*.rbtex"):
    try:
        process = subprocess.Popen(['detex', filename], stdout=subprocess.PIPE)
    except FileNotFoundError:
        raise FileNotFoundError("Please verify that detex is installed on your sysread_booktem. https://github.com/pkubowicz/opendetex")
    
    output, err = process.communicate()
    input_text[filename] = str(output)
    input_text[filename] = ' '.join(input_text[filename].split('\\n'))
for key in input_text:
    print(key)
# Out:
# calculus/ch07/ch07.tex
# fundamentals-of-calculus/ch03/ch03.rbtex
# general_relativity/ch02/ch02.rbtex
# calculus/ch08/ch08.tex
# calculus/ch09/ch09.tex
# special_relativity/ch06/ch06.rbtex
# fundamentals-of-calculus/ch10/ch10.rbtex
# fundamentals-of-calculus/ch09/ch09.rbtex
# special_relativity/ch03/ch03.rbtex
# general_relativity/ch07/ch07.rbtex
# calculus/ch01/ch01.tex
# discover_physics/ch06/ch06.tex
# fundamentals-of-calculus/ch05/ch05.rbtex
# fundamentals-of-calculus/end/photocredits.rbtex
# general_relativity/ch06/ch06.rbtex
# fundamentals-of-calculus/ch07/ch07.rbtex
# general_relativity/ch01/ch01.rbtex
# special_relativity/ch07/ch07.rbtex
# calculus/ch02/ch02.tex
# discover_physics/ch03/ch03.tex
# general_relativity/ch08/ch08.rbtex
# special_relativity/ch02/ch02.rbtex
# special_relativity/ch08/ch08.rbtex
# calculus/ch03/ch03.tex
# fundamentals-of-calculus/ch04/ch04.rbtex
# discover_physics/ch04/ch04.tex
# fundamentals-of-calculus/ch06/ch06.rbtex
# ...

# %%
for filename in glob.glob("ThinkCPP/book/ch*.tex"):
    try:
        process = subprocess.Popen(['detex', filename], stdout=subprocess.PIPE)
    except FileNotFoundError:
        raise FileNotFoundError("Please verify that detex is installed on your sysread_booktem. https://github.com/pkubowicz/opendetex")
    
    output, err = process.communicate()
    input_text[filename] = str(output)
    input_text[filename] = ' '.join(input_text[filename].split('\\n'))
for key in input_text:
    print(key)
# Out:
# calculus/ch07/ch07.tex
# fundamentals-of-calculus/ch03/ch03.rbtex
# ThinkCPP/book/cha10.tex
# general_relativity/ch02/ch02.rbtex
# calculus/ch08/ch08.tex
# calculus/ch09/ch09.tex
# special_relativity/ch06/ch06.rbtex
# ThinkCPP/book/cha15.tex
# fundamentals-of-calculus/ch10/ch10.rbtex
# fundamentals-of-calculus/ch09/ch09.rbtex
# special_relativity/ch03/ch03.rbtex
# general_relativity/ch07/ch07.rbtex
# calculus/ch01/ch01.tex
# discover_physics/ch06/ch06.tex
# fundamentals-of-calculus/ch05/ch05.rbtex
# fundamentals-of-calculus/end/photocredits.rbtex
# ThinkCPP/book/cha5.tex
# general_relativity/ch06/ch06.rbtex
# fundamentals-of-calculus/ch07/ch07.rbtex
# general_relativity/ch01/ch01.rbtex
# ThinkCPP/book/cha6.tex
# special_relativity/ch07/ch07.rbtex
# ThinkCPP/book/cha1.tex
# calculus/ch02/ch02.tex
# discover_physics/ch03/ch03.tex
# general_relativity/ch08/ch08.rbtex
# special_relativity/ch02/ch02.rbtex
# ThinkCPP/book/cha8.tex
# ThinkCPP/book/cha14.tex
# ...

# %%
for filename in glob.glob("ThinkJava/thinkjava.tex"):
    try:
        process = subprocess.Popen(['detex', filename], stdout=subprocess.PIPE)
    except FileNotFoundError:
        raise FileNotFoundError("Please verify that detex is installed on your sysread_booktem. https://github.com/pkubowicz/opendetex")
    
    output, err = process.communicate()
    input_text[filename] = str(output)
    input_text[filename] = ' '.join(input_text[filename].split('\\n'))
for key in input_text:
    print(key)
# Out:
# calculus/ch07/ch07.tex
# fundamentals-of-calculus/ch03/ch03.rbtex
# ThinkCPP/book/cha10.tex
# general_relativity/ch02/ch02.rbtex
# calculus/ch08/ch08.tex
# calculus/ch09/ch09.tex
# special_relativity/ch06/ch06.rbtex
# ThinkCPP/book/cha15.tex
# fundamentals-of-calculus/ch10/ch10.rbtex
# fundamentals-of-calculus/ch09/ch09.rbtex
# special_relativity/ch03/ch03.rbtex
# general_relativity/ch07/ch07.rbtex
# calculus/ch01/ch01.tex
# discover_physics/ch06/ch06.tex
# fundamentals-of-calculus/ch05/ch05.rbtex
# fundamentals-of-calculus/end/photocredits.rbtex
# ThinkCPP/book/cha5.tex
# general_relativity/ch06/ch06.rbtex
# fundamentals-of-calculus/ch07/ch07.rbtex
# general_relativity/ch01/ch01.rbtex
# ThinkCPP/book/cha6.tex
# special_relativity/ch07/ch07.rbtex
# ThinkCPP/book/cha1.tex
# calculus/ch02/ch02.tex
# discover_physics/ch03/ch03.tex
# ThinkJava/thinkjava.tex
# general_relativity/ch08/ch08.rbtex
# special_relativity/ch02/ch02.rbtex
# ThinkCPP/book/cha8.tex
# ThinkCPP/book/cha14.tex
# ...

# %%
for filename in glob.glob("javajavajava/texfiles/*.tex"):
    try:
        process = subprocess.Popen(['detex', filename], stdout=subprocess.PIPE)
    except FileNotFoundError:
        raise FileNotFoundError("Please verify that detex is installed on your sysread_booktem. https://github.com/pkubowicz/opendetex")
    
    output, err = process.communicate()
    input_text[filename] = str(output)
    input_text[filename] = ' '.join(input_text[filename].split('\\n'))
for key in input_text:
    print(key)
# Out:
# calculus/ch07/ch07.tex
# javajavajava/texfiles/9.arrays.tex
# javajavajava/texfiles/5.data.tex
# javajavajava/texfiles/b.tex
# general_relativity/ch02/ch02.rbtex
# calculus/ch09/ch09.tex
# special_relativity/ch06/ch06.rbtex
# javajavajava/texfiles/0.intro.tex
# fundamentals-of-calculus/ch09/ch09.rbtex
# fundamentals-of-calculus/ch05/ch05.rbtex
# javajavajava/texfiles/fm.tex
# general_relativity/ch01/ch01.rbtex
# javajavajava/texfiles/h.tex
# javajavajava/texfiles/figures.tex
# ThinkCPP/book/cha6.tex
# special_relativity/ch07/ch07.rbtex
# javajavajava/texfiles/15.sockets.tex
# discover_physics/ch03/ch03.tex
# javajavajava/texfiles/16.datastructs.tex
# fundamentals-of-calculus/end/photocredits.rbtex
# javajavajava/texfiles/iftests.tex
# ThinkCPP/book/cha8.tex
# ThinkCPP/book/cha3.tex
# calculus/ch03/ch03.tex
# fundamentals-of-calculus/ch04/ch04.rbtex
# discover_physics/ch04/ch04.tex
# javajavajava/texfiles/preface.tex
# fundamentals-of-calculus/ch06/ch06.rbtex
# ...

# %%
for filename in glob.glob("lm/lm/qm/*.rbtex"):
    try:
        process = subprocess.Popen(['detex', filename], stdout=subprocess.PIPE)
    except FileNotFoundError:
        raise FileNotFoundError("Please verify that detex is installed on your sysread_booktem. https://github.com/pkubowicz/opendetex")
    
    output, err = process.communicate()
    input_text[filename] = str(output)
    input_text[filename] = ' '.join(input_text[filename].split('\\n'))
for key in input_text:
    print(key)
# Out:
# calculus/ch07/ch07.tex
# javajavajava/texfiles/9.arrays.tex
# javajavajava/texfiles/5.data.tex
# javajavajava/texfiles/b.tex
# general_relativity/ch02/ch02.rbtex
# calculus/ch09/ch09.tex
# special_relativity/ch06/ch06.rbtex
# javajavajava/texfiles/0.intro.tex
# fundamentals-of-calculus/ch09/ch09.rbtex
# fundamentals-of-calculus/ch05/ch05.rbtex
# lm/lm/qm/c.rbtex
# javajavajava/texfiles/fm.tex
# general_relativity/ch01/ch01.rbtex
# javajavajava/texfiles/h.tex
# javajavajava/texfiles/figures.tex
# ThinkCPP/book/cha6.tex
# special_relativity/ch07/ch07.rbtex
# javajavajava/texfiles/15.sockets.tex
# discover_physics/ch03/ch03.tex
# javajavajava/texfiles/16.datastructs.tex
# fundamentals-of-calculus/end/photocredits.rbtex
# javajavajava/texfiles/iftests.tex
# ThinkCPP/book/cha8.tex
# ThinkCPP/book/cha3.tex
# calculus/ch03/ch03.tex
# fundamentals-of-calculus/ch04/ch04.rbtex
# discover_physics/ch04/ch04.tex
# javajavajava/texfiles/preface.tex
# fundamentals-of-calculus/ch06/ch06.rbtex
# ...

# %%
for filename in glob.glob("lm/lm/vw/*.rbtex"):
    try:
        process = subprocess.Popen(['detex', filename], stdout=subprocess.PIPE)
    except FileNotFoundError:
        raise FileNotFoundError("Please verify that detex is installed on your sysread_booktem. https://github.com/pkubowicz/opendetex")
    
    output, err = process.communicate()
    input_text[filename] = str(output)
    input_text[filename] = ' '.join(input_text[filename].split('\\n'))
for key in input_text:
    print(key)
# Out:
# calculus/ch07/ch07.tex
# javajavajava/texfiles/9.arrays.tex
# javajavajava/texfiles/5.data.tex
# javajavajava/texfiles/b.tex
# general_relativity/ch02/ch02.rbtex
# lm/lm/vw/c.rbtex
# calculus/ch09/ch09.tex
# special_relativity/ch06/ch06.rbtex
# javajavajava/texfiles/0.intro.tex
# fundamentals-of-calculus/ch09/ch09.rbtex
# fundamentals-of-calculus/ch05/ch05.rbtex
# lm/lm/qm/c.rbtex
# javajavajava/texfiles/fm.tex
# general_relativity/ch01/ch01.rbtex
# javajavajava/texfiles/h.tex
# javajavajava/texfiles/figures.tex
# ThinkCPP/book/cha6.tex
# special_relativity/ch07/ch07.rbtex
# javajavajava/texfiles/15.sockets.tex
# discover_physics/ch03/ch03.tex
# javajavajava/texfiles/16.datastructs.tex
# fundamentals-of-calculus/end/photocredits.rbtex
# javajavajava/texfiles/iftests.tex
# ThinkCPP/book/cha8.tex
# ThinkCPP/book/cha3.tex
# calculus/ch03/ch03.tex
# fundamentals-of-calculus/ch04/ch04.rbtex
# discover_physics/ch04/ch04.tex
# javajavajava/texfiles/preface.tex
# ...

# %%
len_dict = {}
import csv
with open('input.csv', 'w') as f:  # Just use 'w' mode in 3.x
    w = csv.writer(f,delimiter=',')
    #w.writeheader()
    for key in input_text:
        len_dict[key]= len(input_text[key])
        w.writerow([key,input_text[key]])

# %%
csv.field_size_limit(sys.maxsize)
with open('input.csv', 'r') as f:
    w = csv.reader(f,delimiter=',')
    for row in w:
        print(row[0])
        #row[1] contains the corresponding content. row[0] can be made a column f
# Out:
# calculus/ch07/ch07.tex
# javajavajava/texfiles/9.arrays.tex
# javajavajava/texfiles/5.data.tex
# javajavajava/texfiles/b.tex
# general_relativity/ch02/ch02.rbtex
# lm/lm/vw/c.rbtex
# calculus/ch09/ch09.tex
# special_relativity/ch06/ch06.rbtex
# javajavajava/texfiles/0.intro.tex
# fundamentals-of-calculus/ch09/ch09.rbtex
# fundamentals-of-calculus/ch05/ch05.rbtex
# lm/lm/qm/c.rbtex
# javajavajava/texfiles/fm.tex
# general_relativity/ch01/ch01.rbtex
# javajavajava/texfiles/h.tex
# javajavajava/texfiles/figures.tex
# ThinkCPP/book/cha6.tex
# special_relativity/ch07/ch07.rbtex
# javajavajava/texfiles/15.sockets.tex
# discover_physics/ch03/ch03.tex
# javajavajava/texfiles/16.datastructs.tex
# fundamentals-of-calculus/end/photocredits.rbtex
# javajavajava/texfiles/iftests.tex
# ThinkCPP/book/cha8.tex
# ThinkCPP/book/cha3.tex
# calculus/ch03/ch03.tex
# fundamentals-of-calculus/ch04/ch04.rbtex
# discover_physics/ch04/ch04.tex
# javajavajava/texfiles/preface.tex
# ...
